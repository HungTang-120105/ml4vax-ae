# %%
import pandas as pd

# Đọc dữ liệu
df_data = pd.read_csv("../data/2025VAERSDATA.csv", encoding='iso-8859-1', low_memory=False)
df_symptoms = pd.read_csv("../data/2025VAERSSYMPTOMS.csv", encoding='iso-8859-1', low_memory=False)
df_vax = pd.read_csv("../data/2025VAERSVAX.csv", encoding='iso-8859-1', low_memory=False)

# Gộp dữ liệu theo VAERS_ID
df = df_data.merge(df_vax, on="VAERS_ID").merge(df_symptoms, on="VAERS_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 # Đọc dữ liệu
# ----> 4 df_data = pd.read_csv("../data/2025VAERSDATA.csv", encoding='iso-8859-1', low_memory=False)
#       5 df_symptoms = pd.read_csv("../data/2025VAERSSYMPTOMS.csv", encoding='iso-8859-1', low_memory=False)
#       6 df_vax = pd.read_csv("../data/2025VAERSVAX.csv", encoding='iso-8859-1', low_memory=False)
#
# ...

# %%
import nbformat

with open("preprocessing.ipynb", "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)  # hoặc as_version=5 nếu bạn dùng nbformat 5
print("Notebook is valid!")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File d:\Mhung\Project\PredictingAdverseEventsOnCovidVaccine\env\Lib\site-packages\nbformat\reader.py:19, in parse_json(s, **kwargs)
#      18 try:
# ---> 19     nb_dict = json.loads(s, **kwargs)
#      20 except ValueError as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
# ...
